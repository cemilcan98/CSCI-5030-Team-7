# %%
#All imports
import re
import unicodedata
import spacy
from tqdm import tqdm
import pandas as pd
import numpy as np
import random
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!tar -xvf drive/MyDrive/GEC/lang8.bea19.tar.gz
# Out:
# lang8.train.auto.bea19.m2
# lang8_to_m2.py
# readme.txt

# %%
with open('/content/drive/MyDrive/Grammar/V4/lang8.train.auto.bea19.m2') as f: #lang8.train.auto.bea19.m2
  data = f.readlines()

# %%
#No of lines in the data
print(len(data))
# Out:
# 4015882

# %%
# Apply the edits of a single annotator to generate the corrected sentences.
m2 = open('/content/drive/MyDrive/Grammar/V4/lang8.train.auto.bea19.m2').read().strip().split("\n\n")
out = open('/content/drive/MyDrive/Grammar/V4/corrected.txt', "w")
in_ = open('/content/drive/MyDrive/Grammar/V4/error.txt', "w")
# Do not apply edits with these error types
skip = {"noop", "UNK", "Um"}

for sent in tqdm(m2):
  #print(sent)
  sent = sent.split("\n")
  cor_sent = sent[0].split()[1:] # Ignore "S "

  in_.write(" ".join(sent[0].split()[1:])+"\n" )
  #print('ORIGINAL',sent[0].split()[1:])
  
  edits = sent[1:]
  offset = 0
  for edit in edits:
    edit = edit.split("|||")
    if edit[1] in skip: continue # Ignore certain edits
    coder = int(edit[-1])
    if coder != 0: continue # Ignore other coders
    span = edit[0].split()[1:] # Ignore "A "
    start = int(span[0])
    end = int(span[1])
    cor = edit[2].split()
    cor_sent[start+offset:end+offset] = cor
    offset = offset-(end-start)+len(cor)

  #print('CORRECT',cor_sent)
  out.write(" ".join(cor_sent)+"\n")
# Out:
# 100%|██████████| 1037561/1037561 [00:09<00:00, 103786.56it/s]

# %%
with open('/content/drive/MyDrive/Grammar/V4/corrected.txt') as f:
  correct_data = f.read()

with open('/content/drive/MyDrive/Grammar/V4/error.txt') as f:
  error_data = f.read()

# %%
final_data = pd.DataFrame(columns = ['error', 'correct'])

final_data['correct'] = correct_data.split('\n')
final_data['error'] = error_data.split('\n')[:len(final_data['correct'])]

# %%
final_data.describe()
# Out:
#           error  correct
# count   1036918  1036918
# unique   943363   937366
# top         URL      URL
# freq       2762     2759

# %% [markdown]
# - Thus we obtain 1037481 rows of train data, out of which 943888 are unique
# - freq is the max frequency of a single entry

# %%
pd.options.display.max_colwidth = 600
final_data[:50]
# Out:
#                                                                                                                                         error                                                                                                                                    correct
# 0                                                                                                               Good luck on your new start !                                                                                                              Good luck on your new start !
# 1                                                                                             My teacher is going to move to change his job .                                                                                            My teacher is going to move to change his job .
# 2                                  He is a so nice guy and taught me English very kindly and was willing to accept my getting off the track .                                 He is a so nice guy and taught me English very kindly and was willing to accept my getting off the track .
# 3                                                                                            And he took in my favorite subject like soccer .                                                                                          And he took in my favorite subjects like soccer .
# 4                                                                                         Actually , who let me know about Lang - 8 was him .                                                                               Actually , he was the one who let me know about Lang - 8 . .
# 5                                                                                         He is also good at Japanese and studies ' Kanji ' .                                                                                        He is also good at Japanese and studies ' Kanji ' .
# 148                                                   When she has had her food , she always prances around the living room merrily .                                                  When she has had her food , she always prances around the living room merrily .
# 149                                                                                                       And she loves basking too .                                                                                                      And she loves basking too .

# %%
final_data.to_csv("/content/drive/MyDrive/Grammar/V4/raw_data.csv", index = False)

# %% [markdown]
# Load the saved raw data

# %%
final_data = pd.read_csv("/content/drive/MyDrive/Grammar/V4/raw_data.csv")

# %% [markdown]
# Remove duplicate rows from data

# %%
final_data.describe()
# Out:
#           error  correct
# count   1036917  1036916
# unique   943362   937364
# top         URL      URL
# freq       2762     2759

# %%
final_data = final_data.drop_duplicates()

# %%
final_data.describe()
# Out:
#                      error              correct
# count               950146               950145
# unique              943362               937364
# top     Nice to meet you .  What do you think ?
# freq                    11                   31

# %%
final_data = final_data.dropna()

# %%
final_data.describe()
# Out:
#                      error              correct
# count               950145               950145
# unique              943361               937364
# top     Nice to meet you .  What do you think ?
# freq                    11                   31

# %% [markdown]
# Max length of sentences

# %%
len_1 = [ len(final_data['correct'].iloc[i]) for i in range(len(final_data['correct'])) ]
len_2= [ len(final_data['error'].iloc[i]) for i in range(len(final_data['error'])) ]

# %%
sns.set_theme()
ax = sns.histplot(data=len_1)
ax.set_xlabel('Number of words in the grammatically correct sentences')
# Out:
# Text(0.5, 0, 'Number of words in the grammatically correct sentences')

# %%
sns.set_theme()
ax = sns.histplot(data=len_2)
ax.set_xlabel('Number of words in the grammatically incorrect sentences')
# Out:
# Text(0.5, 0, 'Number of words in the grammatically incorrect sentences')

# %%
for i in range(0, 100, 10):
  print(np.percentile(len_1,i))
# Out:
# 1.0
# 20.0
# 28.0
# 35.0
# 41.0
# 48.0
# 56.0
# 66.0
# 79.0
# 101.0

# %%
for i in range(0, 100, 10):
  print(np.percentile(len_2,i))
# Out:
# 1.0
# 19.0
# 27.0
# 34.0
# 40.0
# 47.0
# 55.0
# 64.0
# 77.0
# 100.0

# %% [markdown]
# Remove sentences that:
# - have less than equal to 5 words
# - have more than or equal to 30 words
# - have the same error sentence and correct sentence

# %%
for i, row in enumerate(final_data['error']):
  #print(i, row)
  if row.split(" ") == final_data['correct'].iloc[i].split(" ") or len(row.split(" ")) >= 15 or len(row.split(" ")) <= 5:
    final_data.iloc[i] = np.nan

# %%
final_data = final_data.dropna()

# %%
final_data.describe()
# Out:
#                              error                         correct
# count                       290087                          290087
# unique                      289380                          288024
# top     Today , I start Lang - 8 .  This is my first diary entry .
# freq                             5                              20

# %%
final_data

# %% [markdown]
# Check for missing values

# %%
final_data.isna().any()
# Out:
# error      False
# correct    False
# dtype: bool

# %% [markdown]
# Basic preprocessing :
# - Decontractions like do n't, I 'm,
# - Handle : D, x D etc
# - Remove brackets, remove text within it : "And I think it 's fun , right ?"	"And I think it 's fun , right ? ( YEAH ! )"
#
# Note: There is noise in the data and use of speacial characters.

# %% [markdown]
# ALSO BIG NOTE:
# - Remove missing, duplicate values.
# - Experiment w keeping same sentences (corr/incorrect)
# - SHAP figures AI explanability, explore!!
# - Can something be done abput the noise in the dataset

# %% [markdown]
# Basic Preprocessing

# %%
def decontracted(phrase):

    # specific
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"gon na", " going to", phrase)
    phrase = re.sub(r"wan na", " want to", phrase)
    phrase = re.sub(r"gonna", " going to", phrase)
    phrase = re.sub(r"wanna", " want to", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub("\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
        
    return phrase

def clean_text(t):

  #print(t)

  t = unicodedata.normalize('NFKD', t).encode('ascii', 'ignore').decode('ascii') #No need to normalize as text is already an <str> with utf-8 character set
  t = decontracted(t)

  t = re.sub(r'x D', '', t)
  t = re.sub(r': D', '', t)
  t = re.sub(r': P', '', t)

  t = re.sub(r'xD', '', t)
  t = re.sub(r':D', '', t)
  t = re.sub(r':P', '', t)

  #If brackets in text, remove text within brackets
  if '(' in t and ')' in t:
    try:
      t = re.sub(t.split("(")[-1].split(")")[0], '', t)
    except:
      pass
    #t = re.sub("(", '', t)
    #t = re.sub(")", '', t)
  
  #Replace all characters except these with space
  t = re.sub(r'[^A-Za-z;!?.,\-\' ]+', ' ', t)

  #If semicolon in text, remove the part after semicolon till fullstop (since we don't know if the text after semicolon is a continuation of the sentence or a new context altogether)
  #if ';' in t:
  #  t = re.sub(';', ' , ', t)

  t = re.sub(r'\.+',r' .',t)
  t = re.sub(r'\;+',r' , ',t)
  t = re.sub(r'!+',r' !',t )
  t = re.sub(r'\?+',r' ?',t )
  t = re.sub(r'\-+',r' - ',t )
  t = re.sub(r'\,+',r' , ',t )
  t = re.sub(r'\'+',r" ' ",t)
  t = re.sub(' +', ' ', t)

  return t

# %%
final_data['correct'] = final_data['correct'].apply(clean_text)
final_data['error'] = final_data['error'].apply(clean_text)

# %%
final_data[:50]

# %%
final_data[50:100]
# Out:
#                                                                   error                                                                 correct
# 199                   I am listening to music with the commuter train .                         I am listening to music on the commuter train .
# 200            Today , I listen the music , it looks like in the cafe .             Today , I listen the music , it feels like I am in a cafe .
# 209                                    Spring is very exciting season .                                      Spring is a very exciting season .
# 211                              Japanese school , work starts spring .              In Japan , the new school and work year starts in spring .
# 212                       I hope to get any quarifications in english .                                 I hope to become qualified in English .
# 213                                   I hope to get my new promotions .                                         I hope to get a new promotion .
# 215                                Everyday starts new thinngs to try .                                Everyday , there are new things to try .
# 221                                    . . . No , extremely sometimes .                                            . . . No , very frequently .
# 222                   Since today , I am going to try write a diary ! !           Starting today , I am going to try write a diary everyday ! !
# 223                                Today is nothing specal to write ! !                                   Today has nothing specal to write ! !
# 235                            It is kind of Tai - wan stayle massage .                               It is a kind of Tai - wan style massage .
# 240  After that , I went to a fittness club which has bedrock bathing .       After that , I went to a fitness club which has bedrock bathing .
# 241                                I feel relax to take a bedrock bath                                   I felt relaxed to take a bedrock bath
# 244                        I am went to Sendai to business trip today .                             I went to Sendai as a business trip today .
# 245                     The special product in Sendai is a cow tongue .                      The special product of Sendai is a cow is tongue .
# 529              I believe this will lead them to accepting more things .                            I believe this will lead them to accepting more challenges .
# 530       That is why I am very excited with teaching studens English ! !                             That is why I am very excited to teach students English ! !
# 532                                      It is cloudy or rainy recently .                                         It is It is been cloudy or and rainy recently .
# 535    It cost six dollars to washing and cost six dollars to the dryer .  It cost six dollars to washing for the laundry and cost six dollars to for the dryer .
# 536                               When I washing ended , it was evening .                    When I washing ended , it was evening . Laundry ended till evening .
# 538                              The shop of inner decorating was green .                                         The shop of inner decorating decors was green .
# 545                       They were easy cooking but they tasted nice ! !                                      They were easy to cooking but they tasted nice ! !

# %%
final_data.describe()
# Out:
#          error correct
# count   290087  290087
# unique  288570  286826
# top
# freq       544     578

# %%
final_data = final_data.drop_duplicates()
final_data = final_data.dropna()

# %%
final_data.describe()
# Out:
#          error correct
# count   289417  289417
# unique  288570  286826
# top
# freq        32      70

# %%
final_data.to_csv('/content/drive/MyDrive/Grammar/V4/preprocessed_15.csv', index = False)

# %% [markdown]
# Load data from disk and check for missing values

# %%
final_data = pd.read_csv('/content/drive/MyDrive/Grammar/V4/preprocessed_15.csv')

# %%
for i, row in enumerate(final_data['error']):
  if row.split(" ") == final_data['correct'].iloc[i].split(" "):
    final_data.iloc[i] = np.nan

# %%
final_data = final_data.dropna()

# %%
final_data.describe()
# Out:
#          error correct
# count   287887  287887
# unique  287058  285337
# top
# freq        31      69

# %%
final_data.to_csv('/content/drive/MyDrive/Grammar/V4/final_preprocessed_15.csv', index = False)

# %% [markdown]
# EDA:
# - Plot word clouds for both input and output sets
# - Analysis of the lengths of inputs and outputs

# %%
#Plot word cloud: https://www.datasciencelearner.com/how-to-create-a-wordcloud-display/#:~:text=You%20can%20use%20any%20python%20visualization%20packages%20for,you%20are%20importing%20the%20matplotlib%20packages%20as%20plt.
text = " ".join(final_data['correct'])

WC = WordCloud(background_color="white").generate(text)

plt.imshow(WC)
plt.axis("off")
plt.show()

# %%
text = " ".join(final_data['error'])

WC = WordCloud(background_color="white").generate(text)

plt.imshow(WC)
plt.axis("off")
plt.show()

# %%
len_1 = [ len(final_data['correct'].iloc[i]) for i in range(len(final_data['correct'])) ]
len_2= [ len(final_data['error'].iloc[i]) for i in range(len(final_data['error'])) ]

# %%
sns.set_theme()
ax = sns.histplot(data=len_1)
ax.set_xlabel('Number of words in the grammatically correct sentences')

# %%
sns.set_theme()
ax = sns.histplot(data=len_2)
ax.set_xlabel('Number of words in the grammatically incorrect sentences')
# Out:
# Text(0.5, 0, 'Number of words in the grammatically incorrect sentences')

# %%
for i in range(0, 100, 10):
  print(np.percentile(len_1,i))
# Out:
# 1.0
# 28.0
# 34.0
# 38.0
# 42.0
# 46.0
# 50.0
# 54.0
# 60.0
# 67.0

# %%
for i in range(0, 100, 10):
  print(np.percentile(len_2,i))
# Out:
# 1.0
# 28.0
# 32.0
# 36.0
# 40.0
# 44.0
# 48.0
# 52.0
# 57.0
# 63.0
